# %% [markdown]
# ***Capstone Guideline : Named Entity Recognition Service***

# %% [markdown]
# Checkpoints :
# 1. Instalasi : 1 poin
# 2. Membuat dan menggunakan model entity recognition : 2 poin
# 4. Membuat api untuk aplikasi entity recognition dengan tampilan web : 2 poin
# 5. Membuat api untuk aplikasi entity recognition tanpa tampilan web : 9 poin
# 6. Melakukan deployment aplikasi pada remote host : 2 poin

# %% [markdown]
# # Instalasi

# %% [markdown]
# Untuk membuat flask named entity recognition, kita dapat menggunakan libary :
# - flask : untuk membuat aplikasi / microservice (install : `pip install flask`)
# - pandas : tools data analysis, digunakan selama pembuatan fitur aplikasi  (install : `pip install pandas`)
# - spacy : model bahasa (install : `pip install spacy`)
# - en_core_web_md : kamus bahasa yang akan digunakan spacy (install : `python -m spacy download en_core_web_md` atau `pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.0.0/en_core_web_md-3.0.0.tar.gz`)
#
# - requests : tools untuk mengirim dan menerima paket, digunakan untuk menguji aplikasi yang sudah dibuat (built-in python)

# %%
from flask import Flask,render_template,url_for,request
import pandas as pd
import spacy
from spacy import displacy
import en_core_web_md
import requests

# %% [markdown]
# # Membuat dan Menggunakan Model NER

# %% [markdown]
# Sebelum memodelkan bahasa /teks, hal pertama yang dibutuhkan adalah membuat model tersebut. Spacy memudahkan kita dengan memberikan model yang sudah dibuat.
#
# Jalankan sintaks berikut untuk meload model bahasa tersebut

# %%
# load model bahasa spacy
nlp = en_core_web_md.load()

# %% [markdown]
# Setelah memiliki model, komponen penting berikutnya dalah data yang akan dimodelkan. Dalam hal ini, kami memberi contoh sample buku Sherlock Holmes dan teks random sebagai data yang akan dimodelkan.

# %%
# load teks sherlock holmes
# f = open('sherlock_holmes.txt', 'r')
# sherlock_holmes = f.read().replace('\n', ' ')
# f.close()

# jika tidak ingin teks yang panjang, bisa gunakan contoh teks sendiri 
text = """This text is an example used for Algoritma's Capstone API Project. 
You can use any named entitiy such person name like Nicola Tesla, Steve Jobs, or even Elon Musk. 
Please mind that the model is trained on formal writing, thus slang will less likely to be recognized correctly."""

# %%
print(text)
# Out:
# This text is an example used for Algoritma's Capstone API Project.
# You can use any named entitiy such person name like Nicola Tesla, Steve Jobs, or even Elon Musk.
# Please mind that the model is trained on formal writing, thus slang will less likely to be recognized correctly.

# %%
# load teks sherlock holmes
f = open('sherlock_holmes.txt', 'r',encoding='utf-8')
sherlock_holmes = f.read().replace('\n', ' ')
f.close()

# %%
print(sherlock_holmes[:500])
# Out:
# A Study In Scarlet PART I.  (Being a reprint from the reminiscences of John H. Watson, M.D., late of the Army Medical Department.) Chapter I. Mr. Sherlock Holmes  In the year 1878 I took my degree of Doctor of Medicine of the University of London, and proceeded to Netley to go through the course prescribed for surgeons in the army. Having completed my studies there, I was duly attached to the Fifth Northumberland Fusiliers as Assistant Surgeon. The regiment was stationed in India at the time, an

# %% [markdown]
# Untuk menggunakan model Entity Recognition milik spacy, cukup masukkan teks sebagai parameter dalam membuat object bahasa seperti contoh berikut:

# %%
doc = nlp(text)

# %%
doc
# Out:
# This text is an example used for Algoritma's Capstone API Project.
# You can use any named entitiy such person name like Nicola Tesla, Steve Jobs, or even Elon Musk.
# Please mind that the model is trained on formal writing, thus slang will less likely to be recognized correctly.

# %%
doc2 = nlp(sherlock_holmes)

# %% [markdown]
# Untuk menampilkan nilai dari teks tersebut, panggil objek `doc` kembali

# %%
doc2[:100]
# Out:
# A Study In Scarlet PART I.  (Being a reprint from the reminiscences of John H. Watson, M.D., late of the Army Medical Department.) Chapter I. Mr. Sherlock Holmes  In the year 1878 I took my degree of Doctor of Medicine of the University of London, and proceeded to Netley to go through the course prescribed for surgeons in the army. Having completed my studies there, I was duly attached to the Fifth Northumberland Fusiliers as Assistant Surgeon. The regiment was stationed in India at the time, and before

# %%
#MELIHAT ENTITAS YG DIDAPATKAN
doc.ents
# Out:
# (Algoritma, Capstone API Project, Nicola Tesla, Steve Jobs)

# %%
doc2.ents[:20]
# Out:
# (John H. Watson,
#  M.D.,
#  the Army Medical Department,
#  Chapter I.,
#  Sherlock Holmes  ,
#  the year 1878,
#  the University of London,
#  Netley,
#  Fifth,
#  India,
#  second,
#  Afghan,
#  Bombay,
#  Berkshires,
#  Maiwand,
#  Jezail,
#  Ghazis,
#  Murray,
#  British,
#  Peshawar)

# %%
#MELIHAT ENTITAS VALUE PADA BARIS KE-1
doc.ents[0].text
# Out:
# 'Algoritma'

# %%
#MELIHAT KATEGORI ENTITTAS PADA BARIS KE-1
doc.ents[0].label_
# Out:
# 'ORG'

# %%
doc2.ents[0].text
# Out:
# 'John H. Watson'

# %%
doc2.ents[0].label_
# Out:
# 'PERSON'

# %% [markdown]
# Untuk mengakes seluruh element entitas , jalankan sintaks berikut :

# %%
# membuat pasangan label dan nilai entitas
d = [(ent.label_, ent.text) for ent in doc.ents]

# transform pasangan label menjadi dataframe 
df = pd.DataFrame(d, columns=['category', 'value'])

# %%
df
# Out:
#   category                 value
# 0      ORG             Algoritma
# 1      ORG  Capstone API Project
# 2   PERSON          Nicola Tesla
# 3   PERSON            Steve Jobs

# %%
d2 = [(ent.label_, ent.text) for ent in doc2.ents]
df2 = pd.DataFrame(d2, columns=['category', 'value'])
df2
# Out:
#       category                        value
# 0       PERSON               John H. Watson
# 1          GPE                         M.D.
# 2          ORG  the Army Medical Department
# 3          LAW                   Chapter I.
# 4       PERSON            Sherlock Holmes
# ...        ...                          ...
# 2375    PERSON                    Forrester
# 2376  CARDINAL                   two-thirds
# 2377  CARDINAL                          one
# 2378    PERSON                      Morstan
# 2379       GPE                         Agra
#
# [2380 rows x 2 columns]

# %%
df2["category"].unique()
# Out:
# array(['PERSON', 'GPE', 'ORG', 'LAW', 'DATE', 'ORDINAL', 'NORP',
#        'CARDINAL', 'FAC', 'TIME', 'WORK_OF_ART', 'PRODUCT', 'LOC',
#        'QUANTITY', 'EVENT', 'LANGUAGE', 'MONEY'], dtype=object)

# %%
df2[df2["category"]=="ORDINAL"]
# Out:
#      category   value
# 8     ORDINAL   Fifth
# 10    ORDINAL  second
# 41    ORDINAL  second
# 42    ORDINAL   first
# 47    ORDINAL   first
# ...       ...     ...
# 2203  ORDINAL   first
# 2237  ORDINAL  second
# 2294  ORDINAL   first
# 2352  ORDINAL   first
# 2372  ORDINAL   first
#
# [89 rows x 2 columns]

# %% [markdown]
# # Membuat API NER dengan tampilan Web

# %% [markdown]
# ## app.py

# %% [markdown]
# Untuk membuat aplikasi NER dengan flask, silakan **lengkapi code berikut** dan salin kedalam file `app.py`.

# %%
from flask import Flask,render_template,url_for,request, jsonify
import re
import pandas as pd
import spacy
from spacy import displacy
import en_core_web_md
import json 

# @TASK : Load model bahasa 
nlp = en_core_web_md.load()
# END OF TASK 

app = Flask(__name__)

@app.route('/')
def index():
    return render_template("index.html")

@app.route('/process',methods=["POST"])
def process():
    if request.method == 'POST':
        choice = request.form['taskoption']
        rawtext = request.form['rawtext']
        doc2 = nlp(rawtext)
        d2 = []
        if len(doc2.ents) > 0:
            for ent in doc2.ents:
                d2.append((ent.label_, ent.text))
                df2 = pd.DataFrame(d2, columns=['category', 'value'])

                # @TASK : COMPLETE THE FOLLOWING CODES
                ORG_named_entity = df2[df2["category"] == "ORG"]["value"] # Subset semua entitas dengan kategori 'ORG'
                PERSON_named_entity = df2[df2["category"] == "PERSON"]["value"] # Subset semua entitas dengan kategori 'PERSON'
                GPE_named_entity = df2[df2["category"] == "GPE"]["value"] # Subset semua entitas dengan kategori 'GPE'
                MONEY_named_entity = df2[df2["category"] == "MONEY"]["value"] # Subset semua entitas dengan kategori 'MONEY'
                NORP_named_entity = df2[df2["category"] == "NORP"]["value"]
                FAC_named_entity = df2[df2["category"] == "FAC"]["value"]
                LOC_named_entity = df2[df2["category"] == "LOC"]["value"]
                PRODUCT_named_entity = df2[df2["category"] == "PRODUCT"]["value"]
                EVENT_named_entity = df2[df2["category"] == "EVENT"]["value"]
                WORK_OF_ART_named_entity = df2[df2["category"] == "WORK_OF_ART"]["value"]
                LAW_named_entity = df2[df2["category"] == "LAW"]["value"]
                LANGUAGE_named_entity = df2[df2["category"] == "LANGUAGE"]["value"]
                DATE_named_entity = df2[df2["category"] == "DATE"]["value"]
                TIME_named_entity = df2[df2["category"] == "TIME"]["value"]
                QUANTITY_named_entity = df2[df2["category"] == "QUANTITY"]["value"]
                ORDINAL_named_entity = df2[df2["category"] == "ORDINAL"]["value"]
                CARDINAL_named_entity = df2[df2["category"] == "CARDINAL"]["value"]
                # END OF TASK 

            if choice == 'organization':
                results = ORG_named_entity
                num_of_results = len(results)
            elif choice == 'person':
                results = PERSON_named_entity
                num_of_results = len(results)
            elif choice == 'geopolitical':
                results = GPE_named_entity
                num_of_results = len(results)
            elif choice == 'money':
                results = MONEY_named_entity
                num_of_results = len(results)
            elif choice == 'norp':
                results = NORP_named_entity
                num_of_results = len(results)
            elif choice == 'fac':
                results = FAC_named_entity
                num_of_results = len(results)
            elif choice == 'loc':
                results = LOC_named_entity
                num_of_results = len(results)
            elif choice == 'product':
                results = PRODUCT_named_entity
                num_of_results = len(results)
            elif choice == 'event':
                results = EVENT_named_entity
                num_of_results = len(results)
            elif choice == 'work_of_art':
                results = WORK_OF_ART_named_entity
                num_of_results = len(results)
            elif choice == 'law':
                results = LAW_named_entity
                num_of_results = len(results)
            elif choice == 'language':
                results = LANGUAGE_named_entity
                num_of_results = len(results)
            elif choice == 'date':
                results = DATE_named_entity
                num_of_results = len(results)
            elif choice == 'time':
                results = TIME_named_entity
                num_of_results = len(results)
            elif choice == 'quantity':
                results = QUANTITY_named_entity
                num_of_results = len(results)
            elif choice == 'ordinal':
                results = ORDINAL_named_entity
                num_of_results = len(results)
            elif choice == 'cardinal':
                results = CARDINAL_named_entity
                num_of_results = len(results)
        else:
            results = pd.DataFrame()
            num_of_results = len(results)

    return render_template("index.html",results=results,num_of_results = num_of_results, original_text = rawtext)


if __name__ == '__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Restarting with windowsapi reloader
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\asus\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3426: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ## menjalankan app.py

# %% [markdown]
# Untuk menjalankan app.py, silakan buka terminal/console/anaconda prompt menuju direktori tempat app.py berada, lalu jalnkan sintaks
# `python app.py` .
#
# Jika code berjalan dengan baik, silakan buka laman yang dirujuk pada console (biasanya http://127.0.0.1:5000/) melalui browser dan aplikasi akan berjalan sesuai tampilan berikut :
#
# ![](assets/default_homepage.png)
# ![](Capture.jpg)

# %% [markdown]
# Setelah aplikasi berjalan, silakan inputkan teks dan pilih kategori yang akan diekstrak, lalu pilih submit. Jika tidak ada eror, maka form result akan memberikan hasil kembalian berupa banyaknya entitas yang dikenali dan list entitas tersebut.

# %% [markdown]
# # Membuat API NER tanpa tampilan WEB

# %% [markdown]
# ## Membuat Endpoint

# %% [markdown]
# Dalam web service, endpoint adalah sebuah alamat spesifik yang ditujukan untuk kebutuhan khusus.
# Sebagai contoh, berikut adalah beberapa endpoint web API milik spotify :
# - https://api.spotify.com/v1/albums{id} : Digunakan untuk mengakses album dengan album id = id
# - https://api.spotify.com/v1/artists/{id} : digunakan untuk mengakses artist dengan artist id = id
# - https://api.spotify.com/v1/tracks/{id} : digunakan untuk mengakses tracks dengan track id = id
#
# Dalam flask, endpoint dinotasikan dengan `@app.route('alamat endpoint')`, diikuti dengan fungsi yang akan dijalankan.
# Sebelumnya, dalam `app.py`, kita sudah membuat sebuah endpoint home ('/') dengan sintaks :
# ```python
# @app.route('/')
# def index():
#     return render_template("index.html")
# ```
#
# Menggunakan sintaks diatas, ketika user mengakses aplikasi kita di menu utama, maka fungsi `index()` akan dijalankan.
#
# Sebagai contoh tambahan, coba salin sintaks berikut kedalam `app.py` dan coba akses endpoint tersebut
#
# ```python
# @app.route('/endpoint_tertentu')
# def nama_fungsi_tertentu():
#     # secara teknis, kita dapat melakukan apapun dalam fungsi ini
#     return ("Fungsi ini akan dijalankan saat endpoint tersebut diakses")
# ```
#
#
# **notes**: nama fungsi dalam aplikasi flask harus unik.

# %% [markdown]
# ## Endpoint Methods

# %% [markdown]
# Senada dengan konsep CRUD (Create, Read, Update, Delete) dalam database, dalam API konsep tersebut diadopsi menjadi :
# - POST(CREATE),
# - GET(READ),
# - PUT(UPDATE),
# - DELETE
#
# Secara konsep, method POST, GET, PUT, dan DELETE dibuat untuk mengatur API agar dapat lebih terstruktur. Meskipun pada prakterknya, endpoint yang kita definisikan menggunakan method "POST" tidaklah harus untuk membuat data. Artinya, tidak ada aturan yang mengharuskan kita untuk menuliskan jenis method dalam setiap endpoints kita (default endpoints menggunakan method GET).
#
# Dalam capstone ini, kita hanya akan berfokus pada 2 jenis method, GET dan POST. Sebagai contoh tambahan, silakan salin sintaks enspoint berikut kedalma `app.py`, lalu jalankan ulang aplikasinya dan lihat perbedaan saat melakukan akses terhadap kedua endpoint tersebut.
#
# ```python
# @app.route('/endpoint_get', methods=['GET'])
# def contoh_get():
#     return ("Contoh endpoint get")
#
# @app.route('/endpoint_post', methods=['POST'])
# def contoh_post():
#     return ("Contoh endpoint post")
#
# @app.route('/endpoint_multi', methods=['GET', 'POST'])
# def multi_method():
#     if request.method == 'POST':
#         return ("Nilai ini akan dikembalikan jika endpoint ini diakses dengan method POST")
#     else :
#         return ("Nilai ini akan dikembalikan jika endpoint ini diakses dengan method GET")
# ```

# %% [markdown]
# **Note : Secara default, mengakses endpoint melaui browser akan menggunakan method 'GET'**.
#
# Untuk mempermudah pengujian, disarankan untuk menggunakan tools lain seperti "postman", atau menggunakan python.

# %% [markdown]
# ## Mengakses endpoint menggunakan python

# %% [markdown]
# Dalam banyak kasus, web API tidak dipanggil melalui browser, melainkan pada level aplikasi / code. Untuk mengakses web api menggunakan python, gunakan `curl` atau `requests`. Code berikut akan mengakses endpoint yang sama dengan method yang berbeda:

# %%
import requests
response_post = requests.request(method='POST', url='http://localhost:5000/endpoint_multi')
response_get = requests.request(method='GET', url='http://localhost:5000/endpoint_multi')

# %% [markdown]
# Respon dari sebuah service web API dibungkus dalam http response. Jika objek `response_post` dipanggil, maka yang tampil adalah nilai kode status repons tersebut (silakan merujuk referensi HTTP response code untuk informasi lebih lengkap) :

# %%
response_post
# Out:
# <Response [200]>

# %%
# secara eksplisit mengambil atribut status code dari objek response
response_post.status_code
# Out:
# 200

# %% [markdown]
# Untuk dapat mengambil konten dari nilai yang diterima, akses atribut .text atau .json jika nilai yang diterima berupa json

# %%
response_post.text
# Out:
# 'Nilai ini akan dikembalikan jika endpoint ini diakses dengan method POST'

# %%
response_get.text
# Out:
# 'Nilai ini akan dikembalikan jika endpoint ini diakses dengan method GET'

# %% [markdown]
# Referensi : [HTTP response code, by mozilla](https://developer.mozilla.org/id/docs/Web/HTTP/Status)

# %% [markdown]
# ## Mengirim data ke endpoint

# %% [markdown]
# Untuk melakukan ekstraksi entitas terhadap data yang kita miliki pada layanan web api, kita harus mengirimkan data tersebut melalui protokol http.
# Method API yang biasa digunakan dalam melayani request tersebut adalah POST.
# Agar data dapat dikirim dengan baik, data harus dikirim dalam bentuk objek JSON (JSON dalam python = Dictionary).
#
#
# Sebagai contoh, sintaks berikut akan mengirimkan data json kedalam endpoint yang dituju.

# %%
# membuat data yang akan dikirim (dalam bentuk dictionary)
data_yang_akan_dikirim = {
    'nama' : 'Steve', 
    'usia' : 12, 
    'pekerjaan' : 'Data Scientist'
}

# endpoint yang akan dituju
endpoint = 'http://localhost:5000/tes_send_json'

# mengeksekusi request
response = requests.request(method='POST', url=endpoint, json=data_yang_akan_dikirim)

# %%
#404 Karena endpoint "/tes_send_json" belum dibuat
response
# Out:
# <Response [404]>

# %% [markdown]
# Jika dijalankan, sintaks diatas tentu akan menghasilkan error. Hal ini dikarenakan pada aplikasi kita belum terdapat endpoint `'/send_json'`.
# Ikuti langkah berikutnya untuk membuat endpoint yang dapat menerima objek yang kita kirim tersebut

# %% [markdown]
# ## Membuat endpoint yang menerima data

# %% [markdown]
# Untuk membaca data yang dikirimkan pada endpoint tertentu, kita dapat menggunakan method method `request.get_json()` dari flask. (Silakan merujuk ke app.py dan pastikan terdapat sintaks `from flask import request`.
#
# Silakan tambahkan endpoint dibawah ini pada `app.py` dan jalankan kembali request pada segmen sebelumnya

# %% [markdown]
# ```python
# @app.route('/tes_send_json', methods=['POST'])
# def tes_send_json():
#     data = request.get_json() # proses membaca json yang dikirim
#     nama = data['nama']
#     usia = data['usia']
#     pekerjaan = data['pekerjaan']
#
#     return ("Halo, {nama}. Usiamu adalah {usia} dan pekerjaanmu adalah {pekerjaan}".format(nama=nama, usia=usia, pekerjaan=pekerjaan))
# ```

# %%
# coba jalankan request di segment sebelumnya

data_yang_akan_dikirim = {
    'nama' : 'Steve', 
    'usia' : 12, 
    'pekerjaan' : 'Data Scientist'
}

endpoint = 'http://localhost:5000/tes_send_json'

response = requests.request(method='POST', url=endpoint, json=data_yang_akan_dikirim)

# %%
# response berhasil, karena endpoint sudah dibuat
response
# Out:
# <Response [200]>

# %%
# isi dari reponse yg brupa string
response.text
# Out:
# 'Halo, Steve. Usiamu adalah 12 dan pekerjaanmu adalah Data Scientist'

# %% [markdown]
# ## Mengembalikan hasil pemrosesan sebagai objek JSON dari endpoint

# %% [markdown]
# Dalam beberapa kasus, analisis atau pengelolaan yang kita lakukan berakhir pada tipe data DataFrame milik pandas. Untuk mengubah DataFrame menjadi json, gunakan method `.to_json()`. Berikut adalah contoh endpoint yang mengembalikan dataframe dalam bentuk json.

# %% [markdown]
# ```python
# @app.route('/tes_return_json', methods=['POST'])
# def tes_return_json():
#     data = request.get_json() # proses membaca json yang dikirim
#     df = pd.DataFrame([data]) # mengolah data menjadi dataframe
#
#     return (df.to_json()) # mengembalikan dataframe dalam bentuk json
# ```

# %%
data_yang_akan_dikirim = {
    'nama' : 'Steve', 
    'usia' : 12, 
    'pekerjaan' : 'Data Scientist'
}

endpoint = 'http://localhost:5000/tes_return_json'

response = requests.request(method='POST', url=endpoint, json=data_yang_akan_dikirim)

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '{"nama":{"0":"Steve"},"usia":{"0":12},"pekerjaan":{"0":"Data Scientist"}}'

# %%
response.json()
# Out:
# {'nama': {'0': 'Steve'},
#  'usia': {'0': 12},
#  'pekerjaan': {'0': 'Data Scientist'}}

# %%
pd.DataFrame(response.json())
# Out:
#     nama  usia       pekerjaan
# 0  Steve    12  Data Scientist

# %% [markdown]
# ## Task : Endpoint

# %% [markdown]
# Sebagai tugas dalam capstone ini, buatlah endpoint yang dapat mengembalikan **semua** jenis entitas dari teks yang dikirim.
#
# Berikut adalah spesifikasi singkat dari endpoint tersebut
# - Input : Teks dalam bentuk JSON, dengan raw teks disimpan dalam elemen "text" seperti contoh berikut:
# ```python
# {
#     "text" : "ini adalah contoh teks yang dikirim"
# }
# ```
# - Output : Bentuk JSON dari dataframe yang berisi 2 kolom (kategori entitas, value).
#
# Untuk menyelesaikan task tersebut silakan lengkapi code endpoint berikut lalu tambahkan pada `app.py`

# %%
@app.route('/get_entities', methods=['POST'])
def get_entities():
    
    # ambil data dari json yang diterima endpoint
    data3 = request.get_json()
    
    # ambil nilai teks dari data
    text3 = data3['text3']
    
    # modelkan teks dengan model spacy 
    doc3 = nlp(text3)
    
    # membuat pasangan label dan nilai entitas
    d3 = [(ent.label_, ent.text) for ent in doc3.ents]

    # transform pasangan label menjadi dataframe 
    df3 = pd.DataFrame(d3, columns=['category', 'value'])
    
    return (df3.to_json())

# %%
# Jalankan sintaks berikut untuk menguji endpoint tersebut

text3 = sherlock_holmes
data3 = {"text3": text3}
url = 'http://localhost:5000/get_entities'
response3 = requests.request(method='POST', url=url, json=data3)
response3.json()
# Out:
# {'category': {'0': 'PERSON',
#   '1': 'GPE',
#   '2': 'ORG',
#   '3': 'LAW',
#   '4': 'PERSON',
#   '5': 'DATE',
#   '6': 'ORG',
#   '7': 'GPE',
#   '8': 'ORDINAL',
#   '9': 'GPE',
#   '10': 'ORDINAL',
#   '11': 'NORP',
#   '12': 'GPE',
#   '13': 'GPE',
#   '14': 'GPE',
#   '15': 'GPE',
#   '16': 'ORG',
#   '17': 'PERSON',
#   '18': 'NORP',
#   '19': 'GPE',
#   '20': 'NORP',
#   '21': 'DATE',
#   '22': 'GPE',
#   '23': 'NORP',
#   '24': 'DATE',
#   '25': 'GPE',
#   '26': 'DATE',
#   '27': 'GPE',
#   '28': 'CARDINAL',
#   '29': 'GPE',
#   '30': 'GPE',
#   '31': 'ORG',
#   '32': 'DATE',
#   '33': 'FAC',
#   '34': 'GPE',
#   '35': 'PERSON',
#   '36': 'GPE',
#   '37': 'GPE',
#   '38': 'GPE',
#   '39': 'PERSON',
#   '40': 'GPE',
#   '41': 'ORDINAL',
#   '42': 'ORDINAL',
#   '43': 'TIME',
#   '44': 'GPE',
#   '45': 'PERSON',
#   '46': 'ORG',
#   '47': 'ORDINAL',
#   '48': 'GPE',
#   '49': 'DATE',
#   '50': 'TIME',
#   '51': 'GPE',
#   '52': 'GPE',
#   '53': 'GPE',
#   '54': 'PERSON',
#   '55': 'PERSON',
#   '56': 'PERSON',
#   '57': 'GPE',
#   '58': 'GPE',
#   '59': 'DATE',
#   '60': 'CARDINAL',
#   '61': 'GPE',
#   '62': 'TIME',
#   '63': 'CARDINAL',
#   '64': 'CARDINAL',
#   '65': 'DATE',
#   '66': 'PERSON',
#   '67': 'GPE',
#   '68': 'DATE',
#   '69': 'ORG',
#   '70': 'ORG',
#   '71': 'PERSON',
#   '72': 'GPE',
#   '73': 'PERSON',
#   '74': 'GPE',
#   '75': 'GPE',
#   '76': 'PERSON',
#   '77': 'GPE',
#   '78': 'CARDINAL',
#   '79': 'FAC',
#   '80': 'DATE',
#   '81': 'CARDINAL',
#   '82': 'TIME',
#   '83': 'TIME',
#   '84': 'DATE',
#   '85': 'TIME',
#   '86': 'GPE',
#   '87': 'GPE',
#   '88': 'GPE',
#   '89': 'LAW',
#   '90': 'WORK_OF_ART',
#   '91': 'DATE',
#   '92': 'CARDINAL',
#   '93': 'PERSON',
#   '94': 'CARDINAL',
#   '95': 'PERSON',
#   '96': 'DATE',
#   '97': 'CARDINAL',
#   '98': 'TIME',
#   '99': 'DATE',
#   '100': 'TIME',
#   '101': 'DATE',
#   '102': 'GPE',
#   '103': 'PERSON',
#   '104': 'LAW',
#   '105': 'DATE',
#   '106': 'GPE',
#   '107': 'DATE',
#   '108': 'NORP',
#   '109': 'PERSON',
#   '110': 'PERSON',
#   '111': 'TIME',
#   '112': 'DATE',
#   '113': 'PERSON',
#   '114': 'CARDINAL',
#   '115': 'CARDINAL',
#   '116': 'DATE',
#   '117': 'TIME',
#   '118': 'TIME',
#   '119': 'PERSON',
#   '120': 'ORDINAL',
#   '121': 'PERSON',
#   '122': 'CARDINAL',
#   '123': 'WORK_OF_ART',
#   '124': 'PRODUCT',
#   '125': 'CARDINAL',
#   '126': 'ORG',
#   '127': 'LOC',
#   '128': 'GPE',
#   '129': 'CARDINAL',
#   '130': 'ORG',
#   '131': 'PERSON',
#   '132': 'ORDINAL',
#   '133': 'LOC',
#   '134': 'CARDINAL',
#   '135': 'PERSON',
#   '136': 'GPE',
#   '137': 'CARDINAL',
#   '138': 'DATE',
#   '139': 'PERSON',
#   '140': 'ORDINAL',
#   '141': 'ORDINAL',
#   '142': 'GPE',
#   '143': 'GPE',
#   '144': 'NORP',
#   '145': 'GPE',
#   '146': 'ORDINAL',
#   '147': 'GPE',
#   '148': 'PERSON',
#   '149': 'PERSON',
#   '150': 'PERSON',
#   '151': 'PERSON',
#   '152': 'CARDINAL',
#   '153': 'PERSON',
#   '154': 'PERSON',
#   '155': 'PERSON',
#   '156': 'PERSON',
#   '157': 'TIME',
#   '158': 'PERSON',
#   '159': 'DATE',
#   '160': 'CARDINAL',
#   '161': 'DATE',
#   '162': 'ORG',
#   '163': 'ORG',
#   '164': 'PERSON',
#   '165': 'PERSON',
#   '166': 'ORG',
#   '167': 'ORG',
#   '168': 'LAW',
#   '169': 'ORG',
#   '170': 'ORG',
#   '171': 'CARDINAL',
#   '172': 'CARDINAL',
#   '173': 'CARDINAL',
#   '174': 'PERSON',
#   '175': 'PERSON',
#   '176': 'TIME',
#   '177': 'CARDINAL',
#   '178': 'LOC',
#   '179': 'FAC',
#   '180': 'CARDINAL',
#   '181': 'PERSON',
#   '182': 'GPE',
#   '183': 'GPE',
#   '184': 'CARDINAL',
#   '185': 'PERSON',
#   '186': 'PERSON',
#   '187': 'GPE',
#   '188': 'PERSON',
#   '189': 'ORG',
#   '190': 'ORG',
#   '191': 'ORDINAL',
#   '192': 'TIME',
#   '193': 'FAC',
#   '194': 'TIME',
#   '195': 'PERSON',
#   '196': 'PERSON',
#   '197': 'PERSON',
#   '198': 'FAC',
#   '199': 'QUANTITY',
#   '200': 'FAC',
#   '201': 'CARDINAL',
#   '202': 'CARDINAL',
#   '203': 'CARDINAL',
#   '204': 'CARDINAL',
#   '205': 'CARDINAL',
#   '206': 'TIME',
#   '207': 'QUANTITY',
#   '208': 'PERSON',
#   '209': 'PERSON',
#   '210': 'PERSON',
#   '211': 'CARDINAL',
#   '212': 'PERSON',
#   '213': 'ORDINAL',
#   '214': 'PERSON',
#   '215': 'PERSON',
#   '216': 'PERSON',
#   '217': 'ORG',
#   '218': 'CARDINAL',
#   '219': 'CARDINAL',
#   '220': 'DATE',
#   '221': 'PERSON',
#   '222': 'CARDINAL',
#   '223': 'DATE',
#   '224': 'GPE',
#   '225': 'PERSON',
#   '226': 'ORG',
#   '227': 'PERSON',
#   '228': 'ORDINAL',
#   '229': 'PERSON',
#   '230': 'GPE',
#   '231': 'DATE',
#   '232': 'PERSON',
#   '233': 'ORG',
#   '234': 'CARDINAL',
#   '235': 'PERSON',
#   '236': 'ORG',
#   '237': 'PERSON',
#   '238': 'PERSON',
#   '239': 'CARDINAL',
#   '240': 'GPE',
#   '241': 'GPE',
#   '242': 'PERSON',
#   '243': 'NORP',
#   '244': 'PERSON',
#   '245': 'GPE',
#   '246': 'PERSON',
#   '247': 'QUANTITY',
#   '248': 'PERSON',
#   '249': 'PERSON',
#   '250': 'CARDINAL',
#   '251': 'PERSON',
#   '252': 'CARDINAL',
#   '253': 'PERSON',
#   '254': 'ORG',
#   '255': 'ORG',
#   '256': 'GPE',
#   '257': 'GPE',
#   '258': 'PERSON',
#   '259': 'ORG',
#   '260': 'CARDINAL',
#   '261': 'ORG',
#   '262': 'GPE',
#   '263': 'TIME',
#   '264': 'PERSON',
#   '265': 'ORG',
#   '266': 'PERSON',
#   '267': 'PERSON',
#   '268': 'PERSON',
#   '269': 'PERSON',
#   '270': 'PERSON',
#   '271': 'PERSON',
#   '272': 'ORDINAL',
#   '273': 'TIME',
#   '274': 'CARDINAL',
#   '275': 'TIME',
#   '276': 'CARDINAL',
#   '277': 'ORG',
#   '278': 'PERSON',
#   '279': 'PERSON',
#   '280': 'PERSON',
#   '281': 'PERSON',
#   '282': 'DATE',
#   '283': 'ORG',
#   '284': 'FAC',
#   '285': 'CARDINAL',
#   '286': 'QUANTITY',
#   '287': 'ORG',
#   '288': 'CARDINAL',
#   '289': 'CARDINAL',
#   '290': 'CARDINAL',
#   '291': 'PERSON',
#   '292': 'PERSON',
#   '293': 'ORG',
#   '294': 'PERSON',
#   '295': 'CARDINAL',
#   '296': 'PERSON',
#   '297': 'NORP',
#   '298': 'PERSON',
#   '299': 'NORP',
#   '300': 'CARDINAL',
#   '301': 'LAW',
#   '302': 'PERSON',
#   '303': 'TIME',
#   '304': 'CARDINAL',
#   '305': 'FAC',
#   '306': 'PERSON',
#   '307': 'PERSON',
#   '308': 'ORDINAL',
#   '309': 'PERSON',
#   '310': 'ORG',
#   '311': 'ORDINAL',
#   '312': 'CARDINAL',
#   '313': 'TIME',
#   '314': 'DATE',
#   '315': 'TIME',
#   '316': 'CARDINAL',
#   '317': 'CARDINAL',
#   '318': 'TIME',
#   '319': 'PERSON',
#   '320': 'TIME',
#   '321': 'CARDINAL',
#   '322': 'CARDINAL',
#   '323': 'CARDINAL',
#   '324': 'QUANTITY',
#   '325': 'CARDINAL',
#   '326': 'ORG',
#   '327': 'ORG',
#   '328': 'PERSON',
#   '329': 'PERSON',
#   '330': 'CARDINAL',
#   '331': 'CARDINAL',
#   '332': 'CARDINAL',
#   '333': 'ORDINAL',
#   '334': 'NORP',
#   '335': 'PERSON',
#   '336': 'PERSON',
#   '337': 'NORP',
#   '338': 'NORP',
#   '339': 'NORP',
#   '340': 'NORP',
#   '341': 'CARDINAL',
#   '342': 'PERSON',
#   '343': 'PERSON',
#   '344': 'TIME',
#   '345': 'ORG',
#   '346': 'CARDINAL',
#   '347': 'TIME',
#   '348': 'TIME',
#   '349': 'EVENT',
#   '350': 'TIME',
#   '351': 'PERSON',
#   '352': 'GPE',
#   '353': 'FAC',
#   '354': 'CARDINAL',
#   '355': 'FAC',
#   '356': 'CARDINAL',
#   '357': 'CARDINAL',
#   '358': 'CARDINAL',
#   '359': 'LOC',
#   '360': 'WORK_OF_ART',
#   '361': 'PERSON',
#   '362': 'CARDINAL',
#   '363': 'PERSON',
#   '364': 'PERSON',
#   '365': 'PERSON',
#   '366': 'CARDINAL',
#   '367': 'ORG',
#   '368': 'ORG',
#   '369': 'PERSON',
#   '370': 'PERSON',
#   '371': 'PERSON',
#   '372': 'PERSON',
#   '373': 'CARDINAL',
#   '374': 'TIME',
#   '375': 'PERSON',
#   '376': 'ORDINAL',
#   '377': 'CARDINAL',
#   '378': 'PERSON',
#   '379': 'ORG',
#   '380': 'PERSON',
#   '381': 'PERSON',
#   '382': 'TIME',
#   '383': 'PERSON',
#   '384': 'GPE',
#   '385': 'PERSON',
#   '386': 'PERSON',
#   '387': 'DATE',
#   '388': 'NORP',
#   '389': 'ORG',
#   '390': 'TIME',
#   '391': 'TIME',
#   '392': 'ORDINAL',
#   '393': 'FAC',
#   '394': 'TIME',
#   '395': 'ORG',
#   '396': 'GPE',
#   '397': 'PERSON',
#   '398': 'DATE',
#   '399': 'PERSON',
#   '400': 'CARDINAL',
#   '401': 'PERSON',
#   '402': 'TIME',
#   '403': 'PERSON',
#   '404': 'NORP',
#   '405': 'TIME',
#   '406': 'TIME',
#   '407': 'DATE',
#   '408': 'ORG',
#   '409': 'LANGUAGE',
#   '410': 'LOC',
#   '411': 'DATE',
#   '412': 'PERSON',
#   '413': 'PERSON',
#   '414': 'PERSON',
#   '415': 'DATE',
#   '416': 'PERSON',
#   '417': 'PERSON',
#   '418': 'TIME',
#   '419': 'FAC',
#   '420': 'PERSON',
#   '421': 'TIME',
#   '422': 'PERSON',
#   '423': 'TIME',
#   '424': 'CARDINAL',
#   '425': 'PERSON',
#   '426': 'WORK_OF_ART',
#   '427': 'PERSON',
#   '428': 'PERSON',
#   '429': 'CARDINAL',
#   '430': 'PERSON',
#   '431': 'GPE',
#   '432': 'PERSON',
#   '433': 'PERSON',
#   '434': 'PERSON',
#   '435': 'PERSON',
#   '436': 'PERSON',
#   '437': 'TIME',
#   '438': 'PERSON',
#   '439': 'PERSON',
#   '440': 'TIME',
#   '441': 'DATE',
#   '442': 'GPE',
#   '443': 'PERSON',
#   '444': 'CARDINAL',
#   '445': 'PERSON',
#   '446': 'CARDINAL',
#   '447': 'GPE',
#   '448': 'PERSON',
#   '449': 'PERSON',
#   '450': 'PERSON',
#   '451': 'PERSON',
#   '452': 'LAW',
#   '453': 'PERSON',
#   '454': 'DATE',
#   '455': 'ORG',
#   '456': 'ORG',
#   '457': 'NORP',
#   '458': 'NORP',
#   '459': 'GPE',
#   '460': 'ORG',
#   '461': 'ORG',
#   '462': 'ORG',
#   '463': 'NORP',
#   '464': 'PERSON',
#   '465': 'FAC',
#   '466': 'ORG',
#   '467': 'GPE',
#   '468': 'NORP',
#   '469': 'DATE',
#   '470': 'PERSON',
#   '471': 'ORG',
#   '472': 'GPE',
#   '473': 'PERSON',
#   '474': 'CARDINAL',
#   '475': 'DATE',
#   '476': 'ORDINAL',
#   '477': 'FAC',
#   '478': 'GPE',
#   '479': 'PERSON',
#   '480': 'FAC',
#   '481': 'GPE',
#   '482': 'PERSON',
#   '483': 'PERSON',
#   '484': 'PERSON',
#   '485': 'ORG',
#   '486': 'ORG',
#   '487': 'PERSON',
#   '488': 'PERSON',
#   '489': 'ORG',
#   '490': 'PERSON',
#   '491': 'PERSON',
#   '492': 'ORG',
#   '493': 'NORP',
#   '494': 'PERSON',
#   '495': 'CARDINAL',
#   '496': 'PERSON',
#   '497': 'PERSON',
#   '498': 'CARDINAL',
#   '499': 'CARDINAL',
#   '500': 'CARDINAL',
#   '501': 'PERSON',
#   '502': 'GPE',
#   '503': 'PERSON',
#   '504': 'TIME',
#   '505': 'CARDINAL',
#   '506': 'PERSON',
#   '507': 'PERSON',
#   '508': 'ORG',
#   '509': 'PERSON',
#   '510': 'DATE',
#   '511': 'CARDINAL',
#   '512': 'PERSON',
#   '513': 'PERSON',
#   '514': 'PERSON',
#   '515': 'PERSON',
#   '516': 'PERSON',
#   '517': 'PERSON',
#   '518': 'ORDINAL',
#   '519': 'NORP',
#   '520': 'PERSON',
#   '521': 'PERSON',
#   '522': 'PERSON',
#   '523': 'ORG',
#   '524': 'CARDINAL',
#   '525': 'FAC',
#   '526': 'PERSON',
#   '527': 'PERSON',
#   '528': 'ORG',
#   '529': 'PERSON',
#   '530': 'ORG',
#   '531': 'ORG',
#   '532': 'PERSON',
#   '533': 'PERSON',
#   '534': 'PERSON',
#   '535': 'PERSON',
#   '536': 'GPE',
#   '537': 'PERSON',
#   '538': 'TIME',
#   '539': 'PERSON',
#   '540': 'CARDINAL',
#   '541': 'CARDINAL',
#   '542': 'CARDINAL',
#   '543': 'CARDINAL',
#   '544': 'CARDINAL',
#   '545': 'ORDINAL',
#   '546': 'TIME',
#   '547': 'PERSON',
#   '548': 'PERSON',
#   '549': 'PERSON',
#   '550': 'PERSON',
#   '551': 'PERSON',
#   '552': 'ORG',
#   '553': 'PERSON',
#   '554': 'DATE',
#   '555': 'PERSON',
#   '556': 'GPE',
#   '557': 'PERSON',
#   '558': 'TIME',
#   '559': 'TIME',
#   '560': 'PERSON',
#   '561': 'CARDINAL',
#   '562': 'PERSON',
#   '563': 'DATE',
#   '564': 'QUANTITY',
#   '565': 'ORG',
#   '566': 'TIME',
#   '567': 'PERSON',
#   '568': 'PERSON',
#   '569': 'PERSON',
#   '570': 'PERSON',
#   '571': 'PERSON',
#   '572': 'TIME',
#   '573': 'PERSON',
#   '574': 'PERSON',
#   '575': 'PERSON',
#   '576': 'PERSON',
#   '577': 'CARDINAL',
#   '578': 'TIME',
#   '579': 'CARDINAL',
#   '580': 'PERSON',
#   '581': 'CARDINAL',
#   '582': 'PERSON',
#   '583': 'PERSON',
#   '584': 'PERSON',
#   '585': 'PERSON',
#   '586': 'FAC',
#   '587': 'PERSON',
#   '588': 'PERSON',
#   '589': 'PERSON',
#   '590': 'PERSON',
#   '591': 'PERSON',
#   '592': 'PERSON',
#   '593': 'PERSON',
#   '594': 'PERSON',
#   '595': 'PERSON',
#   '596': 'PERSON',
#   '597': 'PERSON',
#   '598': 'PERSON',
#   '599': 'PERSON',
#   '600': 'PERSON',
#   '601': 'ORG',
#   '602': 'TIME',
#   '603': 'LAW',
#   '604': 'WORK_OF_ART',
#   '605': 'PERSON',
#   '606': 'CARDINAL',
#   '607': 'PERSON',
#   '608': 'PERSON',
#   '609': 'PERSON',
#   '610': 'PERSON',
#   '611': 'PERSON',
#   '612': 'PERSON',
#   '613': 'ORDINAL',
#   '614': 'PERSON',
#   '615': 'PERSON',
#   '616': 'PERSON',
#   '617': 'PERSON',
#   '618': 'PERSON',
#   '619': 'CARDINAL',
#   '620': 'FAC',
#   '621': 'CARDINAL',
#   '622': 'ORDINAL',
#   '623': 'TIME',
#   '624': 'PERSON',
#   '625': 'FAC',
#   '626': 'PERSON',
#   '627': 'GPE',
#   '628': 'NORP',
#   '629': 'GPE',
#   '630': 'PERSON',
#   '631': 'TIME',
#   '632': 'PERSON',
#   '633': 'DATE',
#   '634': 'TIME',
#   '635': 'TIME',
#   '636': 'TIME',
#   '637': 'ORG',
#   '638': 'ORG',
#   '639': 'FAC',
#   '640': 'PERSON',
#   '641': 'DATE',
#   '642': 'CARDINAL',
#   '643': 'ORDINAL',
#   '644': 'DATE',
#   '645': 'PERSON',
#   '646': 'PERSON',
#   '647': 'PERSON',
#   '648': 'PERSON',
#   '649': 'PERSON',
#   '650': 'ORDINAL',
#   '651': 'PERSON',
#   '652': 'PERSON',
#   '653': 'PERSON',
#   '654': 'QUANTITY',
#   '655': 'GPE',
#   '656': 'DATE',
#   '657': 'LOC',
#   '658': 'PERSON',
#   '659': 'CARDINAL',
#   '660': 'PERSON',
#   '661': 'PERSON',
#   '662': 'PERSON',
#   '663': 'FAC',
#   '664': 'PERSON',
#   '665': 'PERSON',
#   '666': 'DATE',
#   '667': 'CARDINAL',
#   '668': 'CARDINAL',
#   '669': 'PERSON',
#   '670': 'CARDINAL',
#   '671': 'PERSON',
#   '672': 'PERSON',
#   '673': 'PERSON',
#   '674': 'CARDINAL',
#   '675': 'PERSON',
#   '676': 'PERSON',
#   '677': 'CARDINAL',
#   '678': 'CARDINAL',
#   '679': 'PERSON',
#   '680': 'PERSON',
#   '681': 'PERSON',
#   '682': 'PERSON',
#   '683': 'ORDINAL',
#   '684': 'PERSON',
#   '685': 'PERSON',
#   '686': 'PERSON',
#   '687': 'PERSON',
#   '688': 'PERSON',
#   '689': 'CARDINAL',
#   '690': 'PERSON',
#   '691': 'NORP',
#   '692': 'PERSON',
#   '693': 'PERSON',
#   '694': 'FAC',
#   '695': 'PERSON',
#   '696': 'PERSON',
#   '697': 'PERSON',
#   '698': 'PERSON',
#   '699': 'PERSON',
#   '700': 'PERSON',
#   '701': 'PERSON',
#   '702': 'PERSON',
#   '703': 'ORDINAL',
#   '704': 'CARDINAL',
#   '705': 'PERSON',
#   '706': 'PERSON',
#   '707': 'PERSON',
#   '708': 'PERSON',
#   '709': 'CARDINAL',
#   '710': 'PERSON',
#   '711': 'CARDINAL',
#   '712': 'PERSON',
#   '713': 'ORG',
#   '714': 'ORG',
#   '715': 'LAW',
#   '716': 'ORG',
#   '717': 'NORP',
#   '718': 'DATE',
#   '719': 'ORG',
#   '720': 'GPE',
#   '721': 'LOC',
#   '722': 'GPE',
#   '723': 'CARDINAL',
#   '724': 'DATE',
#   '725': 'DATE',
#   '726': 'GPE',
#   '727': 'ORG',
#   '728': 'ORG',
#   '729': 'QUANTITY',
#   '730': 'ORDINAL',
#   '731': 'DATE',
#   '732': 'DATE',
#   '733': 'CARDINAL',
#   '734': 'DATE',
#   '735': 'DATE',
#   '736': 'CARDINAL',
#   '737': 'PERSON',
#   '738': 'PERSON',
#   '739': 'NORP',
#   '740': 'PERSON',
#   '741': 'PERSON',
#   '742': 'PERSON',
#   '743': 'PERSON',
#   '744': 'ORDINAL',
#   '745': 'CARDINAL',
#   '746': 'CARDINAL',
#   '747': 'CARDINAL',
#   '748': 'GPE',
#   '749': 'GPE',
#   '750': 'ORG',
#   '751': 'CARDINAL',
#   '752': 'CARDINAL',
#   '753': 'DATE',
#   '754': 'DATE',
#   '755': 'TIME',
#   '756': 'ORDINAL',
#   '757': 'CARDINAL',
#   '758': 'CARDINAL',
#   '759': 'CARDINAL',
#   '760': 'ORG',
#   '761': 'ORG',
#   '762': 'ORDINAL',
#   '763': 'CARDINAL',
#   '764': 'WORK_OF_ART',
#   '765': 'ORG',
#   '766': 'PERSON',
#   '767': 'CARDINAL',
#   '768': 'CARDINAL',
#   '769': 'ORDINAL',
#   '770': 'CARDINAL',
#   '771': 'CARDINAL',
#   '772': 'CARDINAL',
#   '773': 'CARDINAL',
#   '774': 'CARDINAL',
#   '775': 'PERSON',
#   '776': 'CARDINAL',
#   '777': 'PERSON',
#   '778': 'DATE',
#   '779': 'CARDINAL',
#   '780': 'NORP',
#   '781': 'PERSON',
#   '782': 'GPE',
#   '783': 'NORP',
#   '784': 'GPE',
#   '785': 'NORP',
#   '786': 'PERSON',
#   '787': 'NORP',
#   '788': 'NORP',
#   '789': 'CARDINAL',
#   '790': 'CARDINAL',
#   '791': 'NORP',
#   '792': 'CARDINAL',
#   '793': 'CARDINAL',
#   '794': 'CARDINAL',
#   '795': 'DATE',
#   '796': 'CARDINAL',
#   '797': 'PERSON',
#   '798': 'PERSON',
#   '799': 'NORP',
#   '800': 'CARDINAL',
#   '801': 'DATE',
#   '802': 'PERSON',
#   '803': 'PERSON',
#   '804': 'LAW',
#   '805': 'PERSON',
#   '806': 'GPE',
#   '807': 'LOC',
#   '808': 'NORP',
#   '809': 'GPE',
#   '810': 'CARDINAL',
#   '811': 'DATE',
#   '812': 'ORDINAL',
#   '813': 'CARDINAL',
#   '814': 'PERSON',
#   '815': 'NORP',
#   '816': 'PERSON',
#   '817': 'PERSON',
#   '818': 'ORG',
#   '819': 'CARDINAL',
#   '820': 'CARDINAL',
#   '821': 'PERSON',
#   '822': 'GPE',
#   '823': 'GPE',
#   '824': 'ORG',
#   '825': 'PERSON',
#   '826': 'CARDINAL',
#   '827': 'PERSON',
#   '828': 'DATE',
#   '829': 'TIME',
#   '830': 'TIME',
#   '831': 'DATE',
#   '832': 'CARDINAL',
#   '833': 'CARDINAL',
#   '834': 'CARDINAL',
#   '835': 'CARDINAL',
#   '836': 'LOC',
#   '837': 'LOC',
#   '838': 'PERSON',
#   '839': 'CARDINAL',
#   '840': 'LOC',
#   '841': 'PERSON',
#   '842': 'PERSON',
#   '843': 'PERSON',
#   '844': 'DATE',
#   '845': 'NORP',
#   '846': 'LOC',
#   '847': 'ORDINAL',
#   '848': 'CARDINAL',
#   '849': 'PERSON',
#   '850': 'DATE',
#   '851': 'ORG',
#   '852': 'GPE',
#   '853': 'GPE',
#   '854': 'PERSON',
#   '855': 'NORP',
#   '856': 'CARDINAL',
#   '857': 'CARDINAL',
#   '858': 'ORG',
#   '859': 'PERSON',
#   '860': 'GPE',
#   '861': 'PERSON',
#   '862': 'DATE',
#   '863': 'PERSON',
#   '864': 'PERSON',
#   '865': 'LOC',
#   '866': 'ORG',
#   '867': 'PERSON',
#   '868': 'DATE',
#   '869': 'PERSON',
#   '870': 'GPE',
#   '871': 'PERSON',
#   '872': 'PERSON',
#   '873': 'TIME',
#   '874': 'PERSON',
#   '875': 'CARDINAL',
#   '876': 'DATE',
#   '877': 'DATE',
#   '878': 'CARDINAL',
#   '879': 'GPE',
#   '880': 'LAW',
#   '881': 'PERSON',
#   '882': 'PERSON',
#   '883': 'LOC',
#   '884': 'PERSON',
#   '885': 'NORP',
#   '886': 'NORP',
#   '887': 'CARDINAL',
#   '888': 'DATE',
#   '889': 'NORP',
#   '890': 'ORG',
#   '891': 'GPE',
#   '892': 'ORG',
#   '893': 'ORDINAL',
#   '894': 'NORP',
#   '895': 'NORP',
#   '896': 'DATE',
#   '897': 'LOC',
#   '898': 'ORG',
#   '899': 'WORK_OF_ART',
#   '900': 'PERSON',
#   '901': 'PERSON',
#   '902': 'PERSON',
#   '903': 'NORP',
#   '904': 'PERSON',
#   '905': 'LOC',
#   '906': 'PERSON',
#   '907': 'CARDINAL',
#   '908': 'PERSON',
#   '909': 'PERSON',
#   '910': 'PERSON',
#   '911': 'ORG',
#   '912': 'NORP',
#   '913': 'GPE',
#   '914': 'PERSON',
#   '915': 'PERSON',
#   '916': 'ORDINAL',
#   '917': 'PERSON',
#   '918': 'PERSON',
#   '919': 'PERSON',
#   '920': 'CARDINAL',
#   '921': 'ORG',
#   '922': 'CARDINAL',
#   '923': 'PERSON',
#   '924': 'PERSON',
#   '925': 'DATE',
#   '926': 'PERSON',
#   '927': 'PERSON',
#   '928': 'ORG',
#   '929': 'PERSON',
#   '930': 'CARDINAL',
#   '931': 'NORP',
#   '932': 'GPE',
#   '933': 'DATE',
#   '934': 'PERSON',
#   '935': 'PERSON',
#   '936': 'DATE',
#   '937': 'GPE',
#   '938': 'GPE',
#   '939': 'PERSON',
#   '940': 'ORDINAL',
#   '941': 'NORP',
#   '942': 'PERSON',
#   '943': 'CARDINAL',
#   '944': 'CARDINAL',
#   '945': 'CARDINAL',
#   '946': 'LAW',
#   '947': 'TIME',
#   '948': 'PERSON',
#   '949': 'LOC',
#   '950': 'LOC',
#   '951': 'CARDINAL',
#   '952': 'CARDINAL',
#   '953': 'PERSON',
#   '954': 'PERSON',
#   '955': 'PERSON',
#   '956': 'PERSON',
#   '957': 'PERSON',
#   '958': 'CARDINAL',
#   '959': 'PERSON',
#   '960': 'CARDINAL',
#   '961': 'PERSON',
#   '962': 'ORG',
#   '963': 'PERSON',
#   '964': 'PERSON',
#   '965': 'CARDINAL',
#   '966': 'CARDINAL',
#   '967': 'NORP',
#   '968': 'CARDINAL',
#   '969': 'PERSON',
#   '970': 'PERSON',
#   '971': 'ORG',
#   '972': 'PERSON',
#   '973': 'PERSON',
#   '974': 'PERSON',
#   '975': 'PERSON',
#   '976': 'PERSON',
#   '977': 'ORG',
#   '978': 'PERSON',
#   '979': 'TIME',
#   '980': 'DATE',
#   '981': 'PERSON',
#   '982': 'DATE',
#   '983': 'DATE',
#   '984': 'ORG',
#   '985': 'TIME',
#   '986': 'PERSON',
#   '987': 'CARDINAL',
#   '988': 'CARDINAL',
#   '989': 'DATE',
#   '990': 'DATE',
#   '991': 'PERSON',
#   '992': 'GPE',
#   '993': 'CARDINAL',
#   '994': 'CARDINAL',
#   '995': 'CARDINAL',
#   '996': 'CARDINAL',
#   '997': 'CARDINAL',
#   '998': 'CARDINAL',
#   '999': 'TIME',
#   ...},
#  'value': {'0': 'John H. Watson',
#   '1': 'M.D.',
#   '2': 'the Army Medical Department',
#   '3': 'Chapter I.',
#   '4': 'Sherlock Holmes  ',
#   '5': 'the year 1878',
#   '6': 'the University of London',
#   '7': 'Netley',
#   '8': 'Fifth',
#   '9': 'India',
#   '10': 'second',
#   '11': 'Afghan',
#   '12': 'Bombay',
#   '13': 'Berkshires',
#   '14': 'Maiwand',
#   '15': 'Jezail',
#   '16': 'Ghazis',
#   '17': 'Murray',
#   '18': 'British',
#   '19': 'Peshawar',
#   '20': 'Indian',
#   '21': 'months',
#   '22': 'England',
#   '23': 'Orontes',
#   '24': 'a month later',
#   '25': 'Portsmouth',
#   '26': 'the next nine months',
#   '27': 'England',
#   '28': 'eleven shillings',
#   '29': 'London',
#   '30': 'Empire',
#   '31': 'Strand',
#   '32': 'the very day',
#   '33': 'the Criterion Bar',
#   '34': 'Stamford',
#   '35': 'Bart',
#   '36': 'London',
#   '37': 'Stamford',
#   '38': 'Holborn',
#   '39': 'Watson',
#   '40': 'London',
#   '41': 'second',
#   '42': 'first',
#   '43': 'this morning',
#   '44': 'Stamford',
#   '45': 'Sherlock Holmes',
#   '46': 'I.',
#   '47': 'first',
#   '48': 'Afghanistan',
#   '49': 'weeks',
#   '50': 'morning to night',
#   '51': 'Holborn',
#   '52': 'Stamford',
#   '53': 'Stamford',
#   '54': 'Holmes',
#   '55': 'Watson',
#   '56': 'Sherlock Holmes',
#   '57': 'Stamford',
#   '58': 'Afghanistan',
#   '59': 'years',
#   '60': 'more than one',
#   '61': 'Guiacum',
#   '62': 'a few hours old',
#   '63': 'hundreds',
#   '64': 'one',
#   '65': 'months',
#   '66': 'Von Bischoff',
#   '67': 'Frankfort',
#   '68': 'last year',
#   '69': 'Mason of Bradford',
#   '70': 'Muller',
#   '71': 'Lefevre',
#   '72': 'Montpellier',
#   '73': 'Samson',
#   '74': 'Orleans',
#   '75': 'Stamford',
#   '76': 'Sherlock Holmes',
#   '77': 'Stamford',
#   '78': 'a high three',
#   '79': 'Baker Street',
#   '80': 'days',
#   '81': 'two',
#   '82': 'ungodly hours',
#   '83': 'noon',
#   '84': 'morrow',
#   '85': 'noon',
#   '86': 'Stamford',
#   '87': 'Afghanistan',
#   '88': 'Stamford',
#   '89': 'Chapter II',
#   '90': 'The Science Of Deduction',
#   '91': 'next day',
#   '92': '221b',
#   '93': 'Baker Street',
#   '94': 'two',
#   '95': 'Sherlock Holmes',
#   '96': 'a day',
#   '97': 'two',
#   '98': 'ten at night',
#   '99': 'days',
#   '100': 'morning to night',
#   '101': 'the weeks',
#   '102': 'Stamford',
#   '103': 'Thomas Carlyle',
#   '104': 'the Solar System',
#   '105': 'this nineteenth century',
#   '106': 'London',
#   '107': 'the century',
#   '108': 'British',
#   '109': 'Mendelssohn',
#   '110': 'Lieder',
#   '111': 'an evening',
#   '112': 'the first week',
#   '113': 'Lestrade',
#   '114': 'three',
#   '115': 'four',
#   '116': 'a single week',
#   '117': 'One morning',
#   '118': 'half an hour',
#   '119': 'Sherlock Holmes',
#   '120': '4th',
#   '121': 'Sherlock Holmes',
#   '122': 'One',
#   '123': 'The Book of Life',
#   '124': 'Deceit',
#   '125': 'one',
#   '126': 'Euclid',
#   '127': 'Atlantic',
#   '128': 'Niagara',
#   '129': 'one',
#   '130': 'the Science of Deduction and Analysis',
#   '131': 'Sherlock Holmes',
#   '132': 'third',
#   '133': 'Underground',
#   '134': 'a thousand',
#   '135': 'Sherlock Holmes',
#   '136': 'London',
#   '137': 'a thousand',
#   '138': 'the thousand and first',
#   '139': 'Lestrade',
#   '140': 'second',
#   '141': 'first',
#   '142': 'Afghanistan',
#   '143': 'Afghanistan',
#   '144': 'English',
#   '145': 'Afghanistan',
#   '146': 'second',
#   '147': 'Afghanistan',
#   '148': "Edgar Allen Poe's",
#   '149': 'Dupin',
#   '150': 'Dupin',
#   '151': 'Dupin',
#   '152': 'a quarter',
#   '153': 'Poe',
#   '154': 'Gaboriau',
#   '155': 'Lecoq',
#   '156': 'Lecoq',
#   '157': 'twenty-four hours',
#   '158': 'Lecoq',
#   '159': 'six months',
#   '160': 'two',
#   '161': 'these days',
#   '162': 'Scotland Yard',
#   '163': 'Marines',
#   '164': 'Sherlock Holmes',
#   '165': 'Sherlock Holmes',
#   '166': 'Commissionaire',
#   '167': 'Royal Marine Light Infantry',
#   '168': 'Chapter III',
#   '169': 'Marines',
#   '170': 'Marines',
#   '171': 'two',
#   '172': 'two',
#   '173': 'four',
#   '174': 'Holmes',
#   '175': 'Sherlock Holmes',
#   '176': 'the night',
#   '177': '3',
#   '178': 'Lauriston Gardens',
#   '179': 'the Brixton Road',
#   '180': 'about two',
#   '181': 'Enoch J. Drebber',
#   '182': 'Cleveland',
#   '183': 'Ohio',
#   '184': 'twelve',
#   '185': 'Tobias Gregson',
#   '186': 'Gregson',
#   '187': 'Scotland',
#   '188': 'Lestrade',
#   '189': 'Gregson, Lestrade',
#   '190': 'Co.',
#   '191': 'third',
#   '192': 'A minute later',
#   '193': 'the Brixton Road',
#   '194': 'morning',
#   '195': 'Cremona',
#   '196': 'Amati',
#   '197': 'Holmes',
#   '198': 'the Brixton Road',
#   '199': 'a hundred yards',
#   '200': 'Lauriston Gardens',
#   '201': 'one',
#   '202': 'four',
#   '203': 'two',
#   '204': 'two',
#   '205': 'three',
#   '206': 'the night',
#   '207': 'three-foot',
#   '208': 'Sherlock Holmes',
#   '209': 'Gregson',
#   '210': 'Lestrade',
#   '211': 'two',
#   '212': 'Lestrade',
#   '213': 'third',
#   '214': 'Gregson',
#   '215': 'Sherlock Holmes',
#   '216': 'Lestrade',
#   '217': 'Gregson',
#   '218': 'Two',
#   '219': 'One',
#   '220': 'many weeks',
#   '221': 'Holmes',
#   '222': 'one',
#   '223': 'forty-four years of age',
#   '224': 'London',
#   '225': 'Lestrade',
#   '226': 'Gregson',
#   '227': 'Lestrade',
#   '228': 'second',
#   '229': 'Van Jansen',
#   '230': 'Utrecht',
#   '231': "the year '34",
#   '232': 'Gregson',
#   '233': 'Gregson',
#   '234': 'four',
#   '235': 'Lestrade',
#   '236': 'Gregson',
#   '237': 'Holmes',
#   '238': 'Gregson',
#   '239': '97163',
#   '240': 'Barraud',
#   '241': 'London',
#   '242': 'Gold Albert',
#   '243': 'Russian',
#   '244': 'Enoch J. Drebber',
#   '245': 'Cleveland',
#   '246': 'the E. J. D.',
#   '247': 'seven pounds thirteen',
#   '248': 'Boccaccio',
#   '249': 'Joseph Stangerson',
#   '250': 'Two',
#   '251': 'E. J. Drebber',
#   '252': 'one',
#   '253': 'Joseph Stangerson',
#   '254': 'American Exchange',
#   '255': 'the Guion Steamship Company',
#   '256': 'Liverpool',
#   '257': 'New York',
#   '258': 'Stangerson',
#   '259': 'Gregson',
#   '260': 'one',
#   '261': 'the American Exchange',
#   '262': 'Cleveland',
#   '263': 'this morning',
#   '264': 'Stangerson',
#   '265': 'Gregson',
#   '266': 'Lestrade',
#   '267': 'Gregson',
#   '268': 'Gregson',
#   '269': 'Rachel',
#   '270': 'Rachel',
#   '271': 'Sherlock Holmes',
#   '272': 'first',
#   '273': "last night's",
#   '274': 'two',
#   '275': 'twenty minutes',
#   '276': 'one',
#   '277': 'Gregson',
#   '278': 'Lestrade',
#   '279': "Sherlock Holmes'",
#   '280': 'Lestrade',
#   '281': 'John Rance',
#   '282': '46',
#   '283': 'Audley Court',
#   '284': 'Kennington Park Gate',
#   '285': 'two',
#   '286': 'more than six feet',
#   '287': 'Trichinopoly',
#   '288': 'four',
#   '289': 'three',
#   '290': 'one',
#   '291': 'Lestrade',
#   '292': 'Gregson',
#   '293': 'Poison',
#   '294': 'Sherlock Holmes',
#   '295': 'One',
#   '296': 'Lestrade',
#   '297': 'German',
#   '298': 'Rachel',
#   '299': 'Parthian',
#   '300': 'two',
#   '301': 'Chapter IV',
#   '302': 'John Rance',
#   '303': "one o'clock",
#   '304': '3',
#   '305': 'Lauriston Gardens',
#   '306': 'Sherlock Holmes',
#   '307': 'Lestrade',
#   '308': 'first',
#   '309': 'Holmes',
#   '310': 'I.',
#   '311': 'first',
#   '312': 'two',
#   '313': 'last night',
#   '314': 'a week',
#   '315': 'the night',
#   '316': 'one',
#   '317': 'three',
#   '318': 'morning',
#   '319': 'Gregson',
#   '320': 'the night',
#   '321': 'two',
#   '322': 'nine',
#   '323': 'ten',
#   '324': 'just over six feet',
#   '325': 'four',
#   '326': 'Trichinopoly',
#   '327': 'Trichinopoly',
#   '328': 'Gregson',
#   '329': 'Lestrade',
#   '330': 'two',
#   '331': 'two',
#   '332': 'one',
#   '333': 'second',
#   '334': 'German',
#   '335': 'RACHE',
#   '336': 'Lestrade',
#   '337': 'German',
#   '338': 'German',
#   '339': 'German',
#   '340': 'Latin',
#   '341': 'one',
#   '342': 'Halle',
#   '343': 'Norman Neruda',
#   '344': 'this afternoon',
#   '345': 'Audley Court',
#   '346': 'half',
#   '347': 'ten at night',
#   '348': 'six in the morning',
#   '349': 'the ‘White Hart’',
#   '350': "one o'clock",
#   '351': 'Harry Murcher',
#   '352': 'Holland',
#   '353': 'Henrietta Street',
#   '354': 'about two',
#   '355': 'the Brixton Road',
#   '356': 'two',
#   '357': 'four',
#   '358': 'two',
#   '359': 'Lauriston Gardens',
#   '360': 'Sherlock Holmes',
#   '361': 'Murcher',
#   '362': 'one',
#   '363': 'Gregson',
#   '364': 'Lestrade',
#   '365': 'Murcher',
#   '366': 'two',
#   '367': 'Columbine',
#   '368': 'Banner',
#   '369': 'Sherlock Holmes',
#   '370': 'Holmes',
#   '371': 'Murcher',
#   '372': 'Holmes',
#   '373': 'half',
#   '374': 'last night',
#   '375': 'Holmes',
#   '376': 'second',
#   '377': 'two',
#   '378': 'Norman Neruda',
#   '379': 'Chopin',
#   '380': 'Tra-la-la-',
#   '381': 'Holmes',
#   '382': 'a couple of hours',
#   '383': 'Enoch J. Drebber',
#   '384': 'Cleveland',
#   '385': 'Holmes',
#   '386': 'Darwin',
#   '387': 'centuries',
#   '388': 'Afghan',
#   '389': 'Maiwand',
#   '390': 'evening',
#   '391': 'this morning',
#   '392': 'first',
#   '393': 'Brixton Road',
#   '394': 'this morning',
#   '395': 'the ‘White Hart’ Tavern',
#   '396': 'Holland Grove',
#   '397': 'Watson',
#   '398': '221b',
#   '399': 'Baker Street',
#   '400': 'between eight and nine',
#   '401': 'Drebber',
#   '402': 'an hour',
#   '403': 'Holmes',
#   '404': 'American',
#   '405': "eight o'clock",
#   '406': 'a few minutes',
#   '407': 'yesterday',
#   '408': 'De Jure inter Gentes',
#   '409': 'Latin',
#   '410': 'Lowlands',
#   '411': '1642',
#   '412': 'Charles',
#   '413': 'Guliolmi Whyte',
#   '414': 'William Whyte',
#   '415': 'Some pragmatical seventeenth century',
#   '416': 'Sherlock Holmes',
#   '417': 'Watson',
#   '418': 'evening',
#   '419': 'the Brixton Road',
#   '420': 'Sally',
#   '421': 'last night',
#   '422': 'Sally',
#   '423': 'this night',
#   '424': '13',
#   '425': 'Duncan Street',
#   '426': 'The Brixton Road',
#   '427': 'Sherlock Holmes',
#   '428': 'Sally',
#   '429': '3',
#   '430': 'Mayfield Place',
#   '431': 'Peckham',
#   '432': 'Sawyer',
#   '433': 'Dennis',
#   '434': 'Tom Dennis',
#   '435': 'Sawyer',
#   '436': 'Sherlock Holmes',
#   '437': 'a few seconds',
#   '438': 'Holmes',
#   '439': "Henri Murger's",
#   '440': "Ten o'clock",
#   '441': 'the day',
#   '442': 'Scotland',
#   '443': 'Yarders',
#   '444': 'four',
#   '445': 'Duncan Street',
#   '446': 'Number 13',
#   '447': 'Keswick',
#   '448': 'Sawyer',
#   '449': 'Dennis',
#   '450': 'Sherlock Holmes',
#   '451': 'Holmes',
#   '452': 'Chapter VI',
#   '453': 'Tobias Gregson',
#   '454': 'next day',
#   '455': 'the “Brixton Mystery',
#   '456': 'The Daily Telegraph',
#   '457': 'German',
#   '458': 'Socialists',
#   '459': 'America',
#   '460': 'Vehmgericht',
#   '461': 'Carbonari',
#   '462': 'the Marchioness de Brinvilliers',
#   '463': 'Darwinian',
#   '464': 'Malthus',
#   '465': 'Ratcliff Highway',
#   '466': 'Government',
#   '467': 'England',
#   '468': 'American',
#   '469': 'some weeks',
#   '470': 'Madame Charpentier',
#   '471': 'Torquay Terrace',
#   '472': 'Camberwell',
#   '473': 'Joseph Stangerson',
#   '474': 'two',
#   '475': 'Tuesday',
#   '476': '4th',
#   '477': 'Euston Station',
#   '478': 'Liverpool',
#   '479': 'Drebber',
#   '480': 'the Brixton Road',
#   '481': 'Euston',
#   '482': 'Stangerson',
#   '483': 'Lestrade',
#   '484': 'Gregson',
#   '485': 'Scotland Yard',
#   '486': 'the Continental Governments',
#   '487': 'Stangerson',
#   '488': 'Gregson',
#   '489': 'Scotland Yard',
#   '490': 'Lestrade',
#   '491': 'Gregson',
#   '492': 'Baker Street',
#   '493': 'Arabs',
#   '494': 'Holmes',
#   '495': 'six',
#   '496': 'Wiggins',
#   '497': 'Wiggins',
#   '498': 'one',
#   '499': 'one',
#   '500': 'a dozen',
#   '501': 'Holmes',
#   '502': 'Brixton',
#   '503': 'Gregson',
#   '504': 'a few seconds',
#   '505': 'three',
#   '506': 'Holmes',
#   '507': 'Arthur Charpentier',
#   '508': 'Majesty',
#   '509': 'Gregson',
#   '510': 'the last day',
#   '511': 'two',
#   '512': 'Sherlock Holmes',
#   '513': 'Holmes',
#   '514': 'Lestrade',
#   '515': 'Stangerson',
#   '516': 'Gregson',
#   '517': 'Watson',
#   '518': 'first',
#   '519': 'American',
#   '520': "Tobias Gregson's",
#   '521': 'Holmes',
#   '522': 'John Underwood',
#   '523': 'Sons',
#   '524': '129',
#   '525': 'Camberwell Road',
#   '526': 'Gregson',
#   '527': 'Holmes',
#   '528': 'Underwood',
#   '529': 'Drebber',
#   '530': "Charpentier's Boarding Establishment",
#   '531': 'Torquay Terrace',
#   '532': 'Sherlock Holmes',
#   '533': 'Madame Charpentier',
#   '534': 'Sherlock Holmes',
#   '535': 'Enoch J. Drebber',
#   '536': 'Cleveland',
#   '537': 'Drebber',
#   '538': "eight o'clock",
#   '539': 'Stangerson',
#   '540': 'two',
#   '541': 'one',
#   '542': '9.15',
#   '543': 'one',
#   '544': '11',
#   '545': 'first',
#   '546': 'some seconds',
#   '547': 'Drebber',
#   '548': 'Madame Charpentier',
#   '549': 'Arthur',
#   '550': 'Alice',
#   '551': 'Alice',
#   '552': 'I.',
#   '553': 'Drebber',
#   '554': 'nearly three weeks',
#   '555': 'Stangerson',
#   '556': 'Copenhagen',
#   '557': 'Stangerson',
#   '558': 'The very night',
#   '559': "twelve o'clock",
#   '560': 'Alice',
#   '561': 'one',
#   '562': 'Charpentier',
#   '563': 'the very day',
#   '564': 'fourteen pounds',
#   '565': 'Navy',
#   '566': 'less than an hour',
#   '567': 'Drebber',
#   '568': 'Alice',
#   '569': 'Alice',
#   '570': 'Arthur',
#   '571': 'Arthur',
#   '572': 'The next morning',
#   '573': 'Drebber',
#   '574': 'Charpentier',
#   '575': 'Sherlock Holmes',
#   '576': 'Charpentier',
#   '577': 'one',
#   '578': 'at least two hours',
#   '579': 'four',
#   '580': 'Charpentier',
#   '581': 'two',
#   '582': 'Drebber',
#   '583': 'Holmes',
#   '584': 'Drebber',
#   '585': 'Drebber',
#   '586': 'the Brixton Road',
#   '587': 'Drebber',
#   '588': 'Charpentier',
#   '589': 'Holmes',
#   '590': 'Gregson',
#   '591': 'Drebber',
#   '592': 'Lestrade',
#   '593': 'Jove',
#   '594': 'Lestrade',
#   '595': 'Sherlock Holmes',
#   '596': 'Lestrade',
#   '597': 'Gregson',
#   '598': 'Joseph Stangerson',
#   '599': 'Joseph Stangerson',
#   '600': 'Lestrade',
#   '601': 'Halliday',
#   '602': "about six o'clock this morning",
#   '603': 'Chapter VII.',
#   '604': 'The Darkness  ',
#   '605': 'Lestrade',
#   '606': 'three',
#   '607': 'Gregson',
#   '608': 'Sherlock Holmes',
#   '609': 'Stangerson',
#   '610': 'Lestrade',
#   '611': 'Gregson',
#   '612': 'Lestrade',
#   '613': 'first',
#   '614': 'Gregson',
#   '615': 'Holmes',
#   '616': 'Lestrade',
#   '617': 'Stangerson',
#   '618': 'Drebber',
#   '619': 'one',
#   '620': 'Euston Station',
#   '621': 'about half-past eight',
#   '622': 'third',
#   '623': 'two in the morning',
#   '624': 'Drebber',
#   '625': 'the Brixton Road',
#   '626': 'Stangerson',
#   '627': 'Liverpool',
#   '628': 'American',
#   '629': 'Euston',
#   '630': 'Drebber',
#   '631': 'next morning',
#   '632': 'Holmes',
#   '633': 'yesterday',
#   '634': 'evening',
#   '635': 'This morning',
#   '636': "eight o'clock",
#   '637': 'Halliday',
#   '638': 'Private Hotel',
#   '639': 'Little George Street',
#   '640': 'Stangerson',
#   '641': 'two days',
#   '642': 'nine',
#   '643': 'second',
#   '644': "twenty years'",
#   '645': 'Joseph Stangerson',
#   '646': 'Sherlock Holmes',
#   '647': 'RACHE',
#   '648': 'Lestrade',
#   '649': 'Lestrade',
#   '650': 'second',
#   '651': 'Holmes',
#   '652': 'Stangerson',
#   '653': 'Drebber',
#   '654': 'eighty odd pounds',
#   '655': 'Cleveland',
#   '656': 'about a month ago',
#   '657': 'Europe',
#   '658': 'Holmes',
#   '659': 'two',
#   '660': 'Drebber',
#   '661': 'Stangerson',
#   '662': 'Lestrade',
#   '663': 'the Police Station',
#   '664': 'Holmes',
#   '665': 'Holmes',
#   '666': 'yesterday',
#   '667': 'one',
#   '668': 'two',
#   '669': 'Holmes',
#   '670': 'One half',
#   '671': 'Lestrade',
#   '672': 'Joseph Stangerson',
#   '673': "Sherlock Holmes'",
#   '674': 'two',
#   '675': 'Drebber',
#   '676': 'Stangerson',
#   '677': 'two',
#   '678': 'two',
#   '679': 'Holmes',
#   '680': 'Gregson',
#   '681': 'Sherlock Holmes',
#   '682': 'Charpentier',
#   '683': 'second',
#   '684': 'Lestrade',
#   '685': 'Stangerson',
#   '686': 'Gregson',
#   '687': 'Lestrade',
#   '688': 'Holmes',
#   '689': 'four million',
#   '690': 'Lestrade',
#   '691': 'Arabs',
#   '692': 'Wiggins',
#   '693': 'Holmes',
#   '694': 'Scotland Yard',
#   '695': 'Lestrade',
#   '696': 'Holmes',
#   '697': 'Wiggins',
#   '698': 'Sherlock Holmes',
#   '699': 'Jefferson Hope',
#   '700': 'Enoch Drebber',
#   '701': 'Joseph Stangerson',
#   '702': 'Holmes',
#   '703': 'second',
#   '704': 'two',
#   '705': 'Holmes',
#   '706': 'Gregson',
#   '707': 'Lestrade',
#   '708': 'Holmes',
#   '709': 'four',
#   '710': 'Lestrade',
#   '711': 'half',
#   '712': 'Sherlock Holmes',
#   '713': 'Scotland Yard',
#   '714': 'Saints',
#   '715': 'Chapter I.',
#   '716': 'The Great Alkali Plain  ',
#   '717': 'North American',
#   '718': 'many a long year',
#   '719': 'the Sierra Nevada',
#   '720': 'Nebraska',
#   '721': 'the Yellowstone River',
#   '722': 'Colorado',
#   '723': 'one',
#   '724': 'winter',
#   '725': 'summer',
#   '726': 'Blackfeet',
#   '727': 'the Sierra Blanco',
#   '728': 'the Sierra Blanco',
#   '729': 'fifteen hundred miles',
#   '730': 'fourth',
#   '731': 'eighteen hundred and',
#   '732': 'twenty years',
#   '733': 'two',
#   '734': 'about five years of age',
#   '735': 'three days',
#   '736': 'two',
#   '737': 'Bob',
#   '738': 'Bender',
#   '739': 'Indian',
#   '740': 'Pete',
#   '741': 'McGregor',
#   '742': 'Johnny Hones',
#   '743': 'Bob',
#   '744': 'first',
#   '745': 'three',
#   '746': 'three',
#   '747': 'two',
#   '748': 'Illinois',
#   '749': 'Missouri',
#   '750': 'Plains',
#   '751': 'two',
#   '752': 'two',
#   '753': 'three days',
#   '754': 'three nights',
#   '755': 'another half hour',
#   '756': 'first',
#   '757': 'two',
#   '758': 'two',
#   '759': 'one',
#   '760': 'the Sierra Blanco',
#   '761': 'the Rio Grande',
#   '762': 'third',
#   '763': 'one',
#   '764': 'Redskins',
#   '765': 'Injuns',
#   '766': 'Stangerson',
#   '767': 'one',
#   '768': 'a dozen',
#   '769': 'first',
#   '770': 'three',
#   '771': 'two',
#   '772': 'two',
#   '773': 'One',
#   '774': 'two',
#   '775': 'John Ferrier',
#   '776': 'twenty-one',
#   '777': 'Lucy Ferrier',
#   '778': 'this day',
#   '779': 'one',
#   '780': 'Egyptian',
#   '781': 'Joseph Smith',
#   '782': 'Palmyra',
#   '783': 'Nauvoo',
#   '784': 'the State of Illinois',
#   '785': 'Nauvoo',
#   '786': 'John Ferrier',
#   '787': 'Mormons',
#   '788': 'Mormons',
#   '789': 'one',
#   '790': 'one',
#   '791': 'Mormons',
#   '792': 'Six',
#   '793': 'two',
#   '794': 'four',
#   '795': 'more than thirty years of age',
#   '796': 'two',
#   '797': 'Ferrier',
#   '798': 'Stangerson',
#   '799': 'Mormons',
#   '800': 'two',
#   '801': 'a few days',
#   '802': 'Brigham Young',
#   '803': 'Joseph Smith',
#   '804': 'Chapter II',
#   '805': 'Mormons',
#   '806': 'Mississippi',
#   '807': 'the Rocky Mountains',
#   '808': 'Anglo',
#   '809': 'Utah',
#   '810': 'acres',
#   '811': 'the next summer',
#   '812': 'first',
#   '813': 'two',
#   '814': 'John Ferrier',
#   '815': 'Mormons',
#   '816': 'Lucy Ferrier',
#   '817': 'Stangerson',
#   '818': 'Mormon',
#   '819': 'three',
#   '820': 'twelve',
#   '821': 'Ferrier',
#   '822': 'Stangerson',
#   '823': 'Kemball',
#   '824': 'Johnston',
#   '825': 'Drebber',
#   '826': 'four',
#   '827': 'John Ferrier',
#   '828': 'years',
#   '829': 'morning',
#   '830': 'evening',
#   '831': 'three years',
#   '832': 'six',
#   '833': 'nine',
#   '834': 'twelve',
#   '835': 'half a dozen',
#   '836': 'Salt Lake City',
#   '837': 'Wahsatch Mountains',
#   '838': 'John Ferrier',
#   '839': 'only one',
#   '840': 'Atlantic',
#   '841': 'Ferrier',
#   '842': 'Lucy Ferrier',
#   '843': 'Ferrier',
#   '844': 'the year',
#   '845': 'American',
#   '846': 'Pacific slope',
#   '847': 'first',
#   '848': 'one',
#   '849': 'Lucy Ferrier',
#   '850': 'June',
#   '851': 'the Latter Day Saints',
#   '852': 'California',
#   '853': 'the City of the Elect',
#   '854': 'Lucy Ferrier',
#   '855': 'Indians',
#   '856': 'a half-dozen',
#   '857': 'one',
#   '858': 'Poncho',
#   '859': 'John Ferrier',
#   '860': 'St. Louis',
#   '861': 'Ferrier',
#   '862': 'two months',
#   '863': 'Lucy Ferrier',
#   '864': 'Jefferson Hope',
#   '865': 'Salt Lake City',
#   '866': 'Sierra',
#   '867': 'John Ferrier',
#   '868': 'the last twelve years',
#   '869': 'Lucy',
#   '870': 'California',
#   '871': 'Jefferson Hope',
#   '872': 'Lucy',
#   '873': 'summer evening',
#   '874': 'Lucy',
#   '875': 'two',
#   '876': 'A couple of months',
#   '877': 'two months',
#   '878': 'one',
#   '879': 'Utah',
#   '880': 'Chapter III',
#   '881': 'John Ferrier Talks',
#   '882': 'Jefferson Hope',
#   '883': 'Salt Lake City',
#   '884': "John Ferrier's",
#   '885': 'Mormon',
#   '886': 'Mormon',
#   '887': 'one',
#   '888': 'those days',
#   '889': 'German',
#   '890': 'the Secret Societies of Italy',
#   '891': 'the State of Utah',
#   '892': 'Church',
#   '893': 'first',
#   '894': 'Mormon',
#   '895': 'Indians',
#   '896': 'this day',
#   '897': 'West',
#   '898': 'the Danite Band',
#   '899': 'the Avenging Angels',
#   '900': 'Prophet',
#   '901': 'John Ferrier',
#   '902': 'Ferrier',
#   '903': 'Mormon',
#   '904': 'Ferrier',
#   '905': 'the Chosen Valley',
#   '906': 'John Ferrier',
#   '907': 'one',
#   '908': 'Ferrier',
#   '909': 'Young',
#   '910': 'Ferrier',
#   '911': 'I.',
#   '912': 'Mormons',
#   '913': 'Utah',
#   '914': 'John Ferrier',
#   '915': 'Gentile',
#   '916': 'thirteenth',
#   '917': 'Joseph Smith',
#   '918': 'Gentile',
#   '919': 'John Ferrier',
#   '920': 'one',
#   '921': 'the Sacred Council of Four',
#   '922': '1',
#   '923': 'Stangerson',
#   '924': 'Drebber',
#   '925': 'a month',
#   '926': 'Young',
#   '927': 'John Ferrier',
#   '928': 'the Sierra Blanco',
#   '929': 'Ferrier',
#   '930': 'One',
#   '931': 'Christian',
#   '932': 'Nevada',
#   '933': 'morrow',
#   '934': 'Lucy',
#   '935': 'Prophet',
#   '936': 'a clear month',
#   '937': 'Utah',
#   '938': 'Utah',
#   '939': 'Lucy',
#   '940': 'first',
#   '941': 'American',
#   '942': 'John Ferrier',
#   '943': '1Heber',
#   '944': 'one',
#   '945': 'hundred',
#   '946': 'Chapter IV',
#   '947': 'the morning',
#   '948': 'John Ferrier',
#   '949': 'Salt Lake City',
#   '950': 'the Nevada Mountains',
#   '951': 'two',
#   '952': 'One',
#   '953': 'Ferrier',
#   '954': 'Drebber',
#   '955': 'Joseph Stangerson',
#   '956': 'John Ferrier',
#   '957': 'Stangerson',
#   '958': 'four',
#   '959': 'Drebber',
#   '960': 'seven',
#   '961': 'Stangerson',
#   '962': 'Church',
#   '963': 'Drebber',
#   '964': 'John Ferrier',
#   '965': 'two',
#   '966': 'two',
#   '967': 'Mormons',
#   '968': 'two',
#   '969': 'Ferrier',
#   '970': 'Stangerson',
#   '971': 'the Council of Four',
#   '972': 'Drebber',
#   '973': 'Ferrier',
#   '974': 'Lucy',
#   '975': 'Jefferson',
#   '976': 'Ferrier',
#   '977': 'Church',
#   '978': 'Young',
#   '979': 'next morning',
#   '980': 'Twenty-nine days',
#   '981': 'John Ferrier',
#   '982': 'twenty-nine days',
#   '983': 'the month',
#   '984': 'Young',
#   '985': 'next morning',
#   '986': 'Lucy',
#   '987': '28',
#   '988': '27',
#   '989': 'many days',
#   '990': 'the month',
#   '991': 'John Ferrier',
#   '992': 'Nevada',
#   '993': 'fifteen and fifteen to ten',
#   '994': 'One',
#   '995': 'one',
#   '996': 'five',
#   '997': 'four',
#   '998': 'three',
#   '999': 'one evening',
#   ...}}

# %%
pd.DataFrame(response3.json()).head()
# Out:
#   category                        value
# 0   PERSON               John H. Watson
# 1      GPE                         M.D.
# 2      ORG  the Army Medical Department
# 3      LAW                   Chapter I.
# 4   PERSON            Sherlock Holmes

# %% [markdown]
# ## Task Endpoint (bonus)

# %% [markdown]
# Jika dilihat dari hasil kembalian endpoint sebelumnya nilai return JSON yang dihasilkan sedikit tidak lazim, dimana sewajarnya nilai setiap entitas dikelompokkan sebagai values kedalam setiap kategori.
#
#
# **Bonus Task** : Buatlah endpoint `'/get_entities_normalized'` yang menghasilkan JSON dengan key jenis kategori entitas, dan value berupa list dari entitas dengan kategori yang bersangkutan. Berikut ilustrasi dari nilai return endpoint yang diinginkan :
#
# ```python
# {category1 : [value1, value2, ... , valuen],
#  category2 : [value1, value2, ... , valuen],}
# ```

# %% [markdown]
# # Deployment ke remote host

# %% [markdown]
# ## Upload code ke git repository (github)
#
# 1. Membuat repositori baru
# 2. Mengupload file ke repositori baru dan commit changes

# %% [markdown]
# ## Create Heroku App
#
# 1. Membuat aplikasi baru
# 2. Menyambungkan repositori github kedalam aplikasi baru
# 3. Melakukan deployment
